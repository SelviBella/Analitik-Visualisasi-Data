# %% [markdown]
# # **Noon Perfume Dataset**

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # **Memuat Dataset**

# %%
file = '/content/noon_perfumes_dataset.csv'

# %%
df = pd.read_csv(file)
df
# Out:
#       Unnamed: 0            brand                      name  old_price  \
# 0              0     PACO RABANNE           1 Million Lucky      395.0
# 1              1  Roberto Cavalli         Paradiso Assoluto      415.0
# 2              2       S.T.Dupont               Royal Amber      265.0
# 3              3            GUESS            Seductive Blue      290.0
# 4              4  Roberto Cavalli                      Uomo      260.0
# ...          ...              ...                       ...        ...
# 998          998            GUESS                      Dare      170.0
# 999          999         BURBERRY  For Women EDP Natural Sp      378.0
# 1000        1000            JOVAN           Musk Cologne Sp       55.0
# 1001        1001    SWISS ARABIAN             Layali CPO At      126.0
# 1002        1002          LACOSTE        L.12.12 Blanc-Pure      347.0
#
#       new_price   ml concentration department   scents  \
# 0        244.55  100           EDT        Men    Woody
# ...

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# ## **Business Objective**
# Dataset ini berisi informasi produk parfum yang dijual pada platform e-commerce Noon. Data mencakup berbagai atribut seperti nama produk, brand, kategori, target pengguna, harga, dan rating. Dalam industri e-commerce, harga dan kualitas produk (yang direpresentasikan melalui rating) merupakan faktor penting yang memengaruhi keputusan pembelian konsumen. Oleh karena itu, analisis terhadap distribusi harga, perbedaan antar brand, serta hubungan antara harga dan rating menjadi penting untuk memahami pola pasar parfum di platform tersebut.
#
# Adapun tujuan dari analisis bisnis ini adalah:
#
# 1. Mengidentifikasi distribusi harga produk parfum.
# 2. Menganalisis perbedaan harga berdasarkan brand dan kategori.
# 3. Mengetahui hubungan antara harga dan rating produk.
# 4. Mengidentifikasi segmen parfum dengan rating tertinggi.
# 5. Memberikan insight mengenai posisi pasar brand parfum di platform Noon.

# %% [markdown]
# ## **Assess Situation**
# Sebelum melakukan analisis, kita perlu memahami kondisi dataset dan juga tantangannya. Dikarenakan data diambil melalui web scraping, kemungkinan ada beberapa masalah seperti data kosong (missing values), penulisan brand yang tidak konsisten, atau data yang duplikat. Selain itu, bisa saja terdapat harga yang terlalu tinggi atau terlalu rendah (outlier) yang dapat memengaruhi hasil analisis. Dataset ini juga hanya berasal dari satu platform yaitu Noon, sehingga hasil analisis hanya menggambarkan kondisi di platform tersebut.

# %% [markdown]
# ## **Analytic Goals**
# Berdasarkan tujuan bisnis yang telah ditentukan, maka tujuan analitik yang akan dilakukan adalah:
#
# • Menganalisis distribusi harga produk parfum.
#
# • Membandingkan harga berdasarkan brand dan kategori produk.
#
# • Mengidentifikasi hubungan antara harga dan rating menggunakan analisis korelasi atau visualisasi scatter plot.
#
# • Mengidentifikasi brand atau segmen produk dengan performa terbaik berdasarkan rating dan rentang harga.
#
# Tujuan analitik ini dirancang untuk menjawab permasalahan bisnis secara lebih teknis dan terukur melalui pendekatan Exploratory Data Analysis (EDA).

# %% [markdown]
# ## **Project Plan**
# Rencana pengerjaan analisis dari dataset ini dimulai dengan memahami struktur dataset, seperti jumlah data, nama kolom, dan tipe datanya. Setelah itu dilakukan proses data cleaning untuk menghapus data duplikat, menangani missing values, serta memastikan format data sudah sesuai. Selanjutnya dilakukan statistik deskriptif untuk melihat gambaran umum data, seperti rata-rata harga, harga tertinggi dan terendah, serta jumlah produk pada setiap department. Hal ini bertujuan agar kita memahami kondisi data secara keseluruhan sebelum masuk ke analisis yang lebih dalam.
#
# Kemudian dilakukan visualisasi data menggunakan grafik agar pola dalam data lebih mudah terlihat. Misalnya melihat distribusi harga, membandingkan harga antar department (feminine, masculine, unisex, dan kids), serta melihat hubungan antara harga dengan jumlah seller ratings. Dari situ akan dianalisis apakah terdapat hubungan antar variabel, seperti apakah brand atau department tertentu memiliki kecenderungan harga yang lebih tinggi.Tahap terakhir adalah menyusun insight dan kesimpulan berdasarkan hasil analisis yang telah dilakukan untuk menjawab tujuan bisnis di awal.

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ## **Struktur Data (Informasi Lanjutan)**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1003 entries, 0 to 1002
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1003 non-null   int64
#  1   brand               1003 non-null   object
#  2   name                1003 non-null   object
#  3   old_price           1003 non-null   float64
#  4   new_price           1003 non-null   float64
#  5   ml                  1003 non-null   int64
#  6   concentration       1003 non-null   object
#  7   department          1003 non-null   object
#  8   scents              1003 non-null   object
#  9   base_note           1003 non-null   object
#  10  middle_note         1003 non-null   object
#  11  item_rating         1003 non-null   float64
#  12  seller              1003 non-null   object
#  13  seller_rating       1003 non-null   float64
#  14  num_seller_ratings  1003 non-null   object
# ...

# %% [markdown]
# 1. Unnamed: 0: Jumlah baris: 1003 Tipe data: int64 Deskripsi: Index data
# 2. brand: Jumlah baris: 1003 Tipe data: object Deskripsi: Merek parfum
# 3. name: Jumlah baris: 1003 Tipe data: object Deskripsi: Nama produk parfum
# 4. old_price: Jumlah baris: 1003 Tipe data: float64 Deskripsi: Harga sebelum diskon
# 5. new_price: Jumlah baris: 1003 Tipe data: float64 Deskripsi: Harga setelah diskon
# 6. ml: Jumlah baris: 1003 Tipe data: int64 Deskripsi: Volume parfum (ml)
# 7. concentration: Jumlah baris: 1003 Tipe data: object Deskripsi: Jenis konsentrasi parfum (EDT, EDP, dll)
# 8. department: Jumlah baris: 1003 Tipe data: object Deskripsi: Kategori target (Men/Women/Unisex)
# 9. scents: Jumlah baris: 1003 Tipe data: object Deskripsi: Karakter aroma parfum
# 10. base_note: Jumlah baris: 1003 Tipe data: object Deskripsi: Aroma dasar parfum
# 11. middle_note: Jumlah baris: 1003 Tipe data: object Deskripsi: Aroma tengah parfum
# 12. item_rating: Jumlah baris: 1003 Tipe data: float64 Deskripsi: Rating produk
# 13. seller: Jumlah baris: 1003 Tipe data: object Deskripsi: Nama penjual
# 14. seller_rating: Jumlah baris: 1003 Tipe data: float64 Deskripsi: Rating penjual
# 15. num_seller_ratings: Jumlah baris: 1003 Tipe data: object Deskripsi: Jumlah ulasan/rating penjual

# %% [markdown]
# ## **Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#          Unnamed: 0         brand        name    old_price    new_price  \
# count   1003.000000          1003        1003  1003.000000  1003.000000
# unique          NaN           160         594          NaN          NaN
# top             NaN  Calvin Klein  Pour Homme          NaN          NaN
# freq            NaN            44           8          NaN          NaN
# mean     501.000000           NaN         NaN   321.176022   149.574307
# std      289.685462           NaN         NaN   234.195846   108.686013
# min        0.000000           NaN         NaN     5.350000     5.350000
# 25%      250.500000           NaN         NaN   140.500000    80.325000
# 50%      501.000000           NaN         NaN   310.000000   135.000000
# 75%      751.500000           NaN         NaN   455.000000   198.525000
# max     1002.000000           NaN         NaN  2350.000000   904.850000
#
#                  ml concentration department  scents  \
# ...

# %% [markdown]
# 1. Count (Kelengkapan Data)
#
# Berdasarkan data, total baris produk adalah 1003. Maka dapat disimpulkan:
#
# • Seluruh kolom memiliki 1003 data (tidak terdapat missing values).
#
# Kesimpulan: Dataset lengkap dan siap digunakan untuk analisis tanpa perlu penanganan missing value.
#
#
# 2. Mean vs Median (Distribusi Data)
#
# • Kolom old_price
# ◦ Mean = 321,18
# ◦ Median = 310,00 - Nilai rata-rata sedikit lebih tinggi dari median, menunjukkan adanya beberapa produk dengan harga lama sangat tinggi (cenderung right-skewed).
#
# • Kolom new_price
# ◦ Mean = 149,57
# ◦ Median = 135,00 - Harga setelah diskon relatif lebih rendah dan distribusi masih sedikit condong ke kanan.
#
# • Kolom ml
# ◦ Mean = 92,86
# ◦ Median = 100,00 - Mayoritas parfum berukuran 100 ml.
#
# • Kolom item_rating
# ◦ Mean ≈ 4,53
# ◦ Median ≈ 4,40 - Rating produk relatif tinggi dan cukup stabil.
#
# • Kolom seller_rating
# ◦ Mean ≈ 4,14
# ◦ Median ≈ 3,80 - Rating penjual cukup baik, namun variasinya lebih besar dibanding rating produk.
#
# Kesimpulan: Secara umum, harga parfum bersifat right-skewed (condong ke kanan), sementara rating cenderung tinggi dan stabil.
#
#
# 3. Min dan Max (Validasi Logika)
#
# • old_price
# ◦ Min = 5,35
# ◦ Max = 2350,00
#
# • new_price
# ◦ Min = 5,35
# ◦ Max = 904,85
#
# • ml
# ◦ Min = 1 ml
# ◦ Max = 200 ml
#
# • item_rating
# ◦ Min = 1,00
# ◦ Max = 5,00
#
# • seller_rating
# ◦ Min = 3,50
# ◦ Max = 4,20
#
# Kesimpulan: Rentang harga cukup lebar, menunjukkan variasi produk dari kelas low-end hingga premium. Nilai rating berada dalam batas logis (1–5).
#
#
# 4. Standar Deviasi (Std) – Variabilitas Data
#
# • old_price
# ◦ Std ≈ 234,20 - Variasi harga lama cukup tinggi.
#
# • new_price
# ◦ Std ≈ 108,69 - Harga setelah diskon lebih stabil dibanding harga awal.
#
# • ml
# ◦ Std ≈ 27,50 - Ukuran parfum relatif terkonsentrasi di sekitar 100 ml.
#
# Kesimpulan: Variasi terbesar terdapat pada harga, sedangkan ukuran parfum dan rating relatif lebih konsisten.

# %% [markdown]
# ## **Data Type Check**
#
# Kita akan mengecek tipe data dari setiap kolom apakah sudah sesuai atau tidak. Agar insight serta visualisasi yang akan kita buat menjadi akurat.
#
# Dan dapat dilihat di bawah ini, hampir semua kolom sudah memiliki tipe data yang sesuai. Namun, kolom num_seller_ratings masih bertipe object, seharusnya bertipe numerik karena menunjukkan jumlah rating. Selain itu, semua kolom sudah sesuai.

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# brand                  object
# name                   object
# old_price             float64
# new_price             float64
# ml                      int64
# concentration          object
# department             object
# scents                 object
# base_note              object
# middle_note            object
# item_rating           float64
# seller                 object
# seller_rating         float64
# num_seller_ratings     object
# dtype: object

# %% [markdown]
# ## **Inconsistent Values**
#
#  Pada tahap ini, kita perlu mengecek konsistensi data dalam penulisan agar tidak terjadi perbedaan makna atau duplikasi karena format yang berbeda.

# %% [markdown]
# 1. **brand**
#
# Pada kolom brand, terdapat perbedaan penggunaan huruf kapital, misalnya ada yang ditulis seluruhnya kapital dan ada yang tidak.
# Hal ini perlu distandarisasi (misalnya semua menjadi uppercase atau lowercase) agar analisis kategori brand lebih akurat.

# %%
print(df['brand'].unique())
# Out:
# ['PACO RABANNE' 'Roberto Cavalli' 'S.T.Dupont' 'GUESS' 'HUGO BOSS'
#  'DORALL COLLECTION' 'GUCCI' 'Yves Saint Laurent' 'CERRUTI 1881'
#  'Calvin Klein' 'Rasasi' 'MONTALE' 'CHLOE' 'NARCISO RODRIGUEZ' 'BOUCHERON'
#  'Alina Corel' 'Revlon' 'TED LAPIDUS' 'Britney Spears'
#  'Van Cleef & Arpels' 'Estee Lauder' 'Geoffrey Beene' 'Dolce & Gabbana'
#  'Mancera' 'Dior' 'BURBERRY' 'AIGNER' 'BENTLEY' 'VERSACE' 'Juicy Couture'
#  'Laura Mars' 'GIORGIO ARMANI' 'HERMES' 'Elizabeth Arden' 'Benetton'
#  'Giorgio Beverly Hills' 'Guerlain' 'Jean Paul GAULTIER' 'Ajmal'
#  'J.CASANOVA' 'UNITED COLORS OF BENETTON' 'YSL' 'TOMMY HILFIGER'
#  'RALPH LAUREN' 'EMPORIO ARMANI' 'armani' 'VALENTINO' 'Ard Al Zaafaran'
#  'DKNY' 'CAROLINA HERRERA' 'ELIE SAAB' 'MONTBLANC' 'LACOSTE' 'LE CHAMEAU'
#  'AVON' 'Salvatore Ferragamo' 'Carrera' 'Sedr Al-Khaleej Perfumes'
#  'Dunhill' 'TRUSSARDI' 'Dupont' 'ANGEL SCHLESSER' 'DAVIDOFF' 'CHOPARD'
#  'CARTIER' 'jennifer lopez' 'BVLGARI' 'Ferrari' 'Alrehab' 'Genie'
# ...

# %% [markdown]
# 2. **seller**
#
# Dapat dilihat terdapat ketidakkonsistenan pada kolom seller.
#
# Contohnya terdapat nilai seperti “noon”, “Cute”, dan “Swiss Arabian PerfumesPRICE UPDATE WITH 15% VA…”.
#
# Nilai terakhir mengandung teks tambahan/promosi yang seharusnya bukan bagian dari nama seller. Hal ini menunjukkan adanya inkonsistensi format pada kolom seller dan perlu dibersihkan. Selain itu ada juga perbedaan penulisan antara huruf kapital dan yang tidak yang perlu disesuaikan.

# %%
print(df['seller'].unique())
# Out:
# ['noon' 'rich&light' 'B.A.G' 'Al-Najm' 'AMLAQ' 'Bismat Eatar'
#  'Star.perfume' 'hadayiq baris' 'Kathya' 'Golden Perfumesعطر أصلي 100  %'
#  'neo lek' 'Cute Shop' 'Brand Land' 'KAYA' 'top langri' 'Asrar Aljamal'
#  'MAKE UP' 'Parfume-Stor' 'perfumes--addresses' 'Princess of beauty'
#  'King-Perfume' 'عالم المشاهير' 'beautiful lady' 'Boutique Wareef'
#  'Rose Gallary' 'Beauty Ideas' 'Faces' 'MOON LIGHT' 'Shopping life'
#  'Parisian Store' 'PARFUM.1990' 'Pinch Of Perfum' 'flower'
#  'Beauty Gallery' 'Diorworld' 'Attractive perfume' 'Majestueuse'
#  'Beautiful Live' 'Modon' 'Emper Perfumes' 'Queen Line' 'Tiffany' 'SEDR'
#  'ثروة الجمال' 'the beauty' 'BOUTIQUE PERFUMES' 'Dior Fragrances'
#  'Number One' 'moon perfume' 'Ryhana Perfume' 'Beuatyone1'
#  'noon100  % original genuine product' 'kikup'
#  'Lolita ShopNo Exchange or Return' 'Alabeer' 'Parvant Store' 'Chansles'
#  'hawas' 'Rayhanti' 'Abu Al Tayyeb Perfumes' 'Queen Beauty'
# ...

# %% [markdown]
# ## **Missing values**
#
# Pada tahap ini, kita akan melihat seberapa banyak data yang hilang pada seluruh kolom. Hal ini dilakukan untuk memastikan apakah terdapat nilai kosong yang dapat mempengaruhi hasil analisis.
#
#
# Dan dapat dilihat pada tabel di bawah, seluruh kolom memiliki nilai 0.0% pada Null Ratio.
# Artinya, tidak terdapat missing values pada dataset ini.
#
# Kesimpulan:
# Dataset dalam kondisi lengkap tanpa nilai yang hilang, sehingga tidak diperlukan penanganan missing values sebelum proses analisis lebih lanjut.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                     Null Ratio in %
# Unnamed: 0                      0.0
# brand                           0.0
# name                            0.0
# old_price                       0.0
# new_price                       0.0
# ml                              0.0
# concentration                   0.0
# department                      0.0
# scents                          0.0
# base_note                       0.0
# middle_note                     0.0
# item_rating                     0.0
# seller                          0.0
# seller_rating                   0.0
# num_seller_ratings              0.0

# %% [markdown]
# ## **Duplicated Values**
#
# Pada tahap ini, kita akan mengecek duplikasi pada dataset. Hal ini dilakukan agar dataset memiliki insight dan hasil yang bersih.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, brand, name, old_price, new_price, ml, concentration, department, scents, base_note, middle_note, item_rating, seller, seller_rating, num_seller_ratings]
# Index: []

# %% [markdown]
# Terlihat pada dataset ini tidak ada duplikasi. Maka hal ini tidak perlu ditangani, namun jika ingin menangani anda dapat mengetikkan
#
# df = df.drop_duplicates()

# %% [markdown]
# ## **Outliers**
#
# Pada tahap ini, kita akan melihat nilai ekstrem (outliers) pada kolom yang bertipe data numerik. Hal ini dilakukan agar mendapatkan insight yang akurat sehingga dapat memperkuat analisis yang akan kita bangun nantinya.
#
# Tidak semua kolom harus ditangani, namun kita perlu memahami seberapa besar persentase outliers pada masing-masing kolom.
# Dan terlihat bahwa:
#
# • old_price
#
# Dengan persentase sekitar 1.49%
#
# • new_price
#
# Dengan persentase sekitar 2.79%
#
# • ml
#
# Dengan persentase sekitar 6.18%
#
# • item_rating
#
# Dengan persentase sekitar 5.28%
#
# • seller_rating
#
# Dengan persentase sekitar 2.59%
#
# Kesimpulan: Kolom dengan outliers terbesar terdapat pada ml dan item_rating. Namun secara keseluruhan persentase outliers masih relatif kecil (di bawah 10%), sehingga masih dapat ditoleransi tergantung tujuan analisis yang dilakukan.

# %%
results = []
cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom          Persentase Outliers
# Unnamed: 0                0.000000
# old_price                 1.495513
# new_price                 2.791625
# ml                        6.181456
# item_rating               5.284148
# seller_rating             2.592223

# %% [markdown]
# # **Eksplorasi Data (EDA)**

# %% [markdown]
# ## **Comparison (Perbandingan)**

# %% [markdown]
# Aktivitas: Membandingkan rata-rata harga parfum (new_price) berdasarkan kategori department.
#
# Tujuan: Mengidentifikasi kategori target (Men, Women, Unisex) mana yang memiliki rata-rata harga tertinggi dan membandingkan perbedaannya secara langsung.
#
# Visualisasi: Bar Chart (Grafik Batang).

# %%
harga_department = df.groupby('department')['new_price'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=harga_department.index, y=harga_department.values, palette='viridis', hue=harga_department.index, legend=False)
plt.title('Rata-rata Harga Parfume Berdasarkan Department')
plt.xlabel('Department')
plt.ylabel('Rata-rata Harga')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Berdasarkan hasil output visual yang ditampilkan, terlihat bahwa:
#
# • Kategori Women memiliki rata-rata harga paling tinggi dibandingkan kategori lainnya.
#
# • Kategori Men berada di posisi kedua dengan rata-rata harga yang cukup tinggi namun masih di bawah Women.
#
# • Kategori Unisex memiliki rata-rata harga lebih rendah dibandingkan Women dan Men.
#
# • Kategori Kids Unisex memiliki rata-rata harga paling rendah di antara semua kategori.
#
#
# Kesimpulan:
# Segmentasi harga terlihat jelas berdasarkan target pengguna. Produk Women dan Men cenderung berada pada segmen harga lebih premium, sedangkan Unisex dan terutama Kids Unisex berada pada segmen harga yang lebih terjangkau.

# %% [markdown]
# ## **Composition (Komposisi)**

# %% [markdown]
# Aktivitas: Melihat proporsi atau persentase jumlah produk berdasarkan jenis concentration (EDT, EDP, dll).
#
# Tujuan: Mengetahui jenis konsentrasi parfum mana yang paling mendominasi berdasarkan jumlah produk yang tersedia di website Noon secara keseluruhan.
#
# Visualisasi: Pie Chart (Grafik Lingkaran).

# %%
count_by_concentration = df['concentration'].value_counts().sort_values(ascending=False)

count_by_concentration_top3 = count_by_concentration.head(3)

plt.figure(figsize=(10, 8))
count_by_concentration_top3.plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=140,
    colors=plt.cm.Paired.colors
)

plt.title('Proporsi 3 Konsentrasi Parfum Teratas Berdasarkan Jumlah Produk')
plt.ylabel("")
plt.axis('equal')
plt.show()

# %% [markdown]
# Berdasarkan pie chart, terlihat bahwa konsentrasi parfum didominasi oleh EDT (50.3%) dan EDP (49.4%), dengan proporsi yang hampir seimbang. Hal ini menunjukkan bahwa sebagian besar produk parfum yang tersedia di website Noon berada pada dua jenis konsentrasi tersebut.
#
# Sementara itu, PDT memiliki proporsi yang sangat kecil (0.3%), yang berarti jumlah produknya jauh lebih sedikit dibandingkan EDT dan EDP.
#
# Secara keseluruhan, dapat disimpulkan bahwa pasar parfum di dataset ini hampir sepenuhnya didominasi oleh EDT dan EDP.

# %% [markdown]
# ## **Distribution (Distribusi)**

# %% [markdown]
# Aktivitas: Menganalisis penyebaran nilai new_price pada dataset parfum.
#
# Tujuan: Melihat apakah mayoritas produk berada pada harga rendah, menengah, atau tinggi, serta mendeteksi adanya kemiringan distribusi (skewness).
#
# Visualisasi: Histogram.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['new_price'], bins=20, kde=True)
plt.title('Distribusi Harga Parfum (New Price)')
plt.xlabel('New Price')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Berdasarkan histogram, sebagian besar parfum berada pada rentang harga rendah hingga menengah (di bawah 200). Distribusi terlihat miring ke kanan (right-skewed), yang menunjukkan hanya sedikit produk dengan harga sangat tinggi. Artinya, mayoritas produk berada di segmen terjangkau hingga menengah, dengan beberapa produk premium sebagai outlier.

# %% [markdown]
# ## **Relationship (Hubungan)**

# %% [markdown]
# Aktivitas: Menganalisis hubungan antara new_price dan item_rating pada dataset parfum.
#
# Tujuan: Mengetahui apakah parfum dengan harga lebih tinggi cenderung memiliki rating yang lebih baik, serta melihat kekuatan hubungan antar keduanya.
#
# Visualisasi: Heatmap.

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['new_price', 'item_rating']].corr(),
    annot=True,
    cmap='viridis',
    fmt='.2f' )

plt.title('Korelasi antara New Price dan Item Rating')
plt.show()

# %% [markdown]
# Berdasarkan heatmap korelasi antara new_price dan item_rating, terlihat nilai korelasi sebesar 0.11. Nilai ini menunjukkan hubungan yang sangat lemah dan positif antara harga parfum dan rating produk.
#
# Artinya, kenaikan harga tidak secara signifikan berkaitan dengan kenaikan rating. Dengan kata lain, parfum yang lebih mahal belum tentu memiliki penilaian yang lebih tinggi dari konsumen.
#
# Hal ini menunjukkan bahwa faktor selain harga, seperti kualitas aroma, brand, atau preferensi pribadi, kemungkinan lebih memengaruhi rating produk dibandingkan harga itu sendiri.

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# ### **Tipe Data**

# %%
df['num_seller_ratings'] = pd.to_numeric(df['num_seller_ratings'], errors='coerce')

# %%
df['num_seller_ratings'] = df['num_seller_ratings'].astype('float64')

# %%
df.dtypes
# Out:
# Unnamed: 0              int64
# brand                  object
# name                   object
# old_price             float64
# new_price             float64
# ml                      int64
# concentration          object
# department             object
# scents                 object
# base_note              object
# middle_note            object
# item_rating           float64
# seller                 object
# seller_rating         float64
# num_seller_ratings    float64
# dtype: object

# %% [markdown]
# Mengubah kolom num_selller_ratings dari tipe data object menjadi tipe data float akarena merupakan tipe data numerik.

# %% [markdown]
# ### **Inconsistent Values**

# %%
df['brand'] = df['brand'].str.upper()
print(df['brand'].unique())
# Out:
# ['PACO RABANNE' 'ROBERTO CAVALLI' 'S.T.DUPONT' 'GUESS' 'HUGO BOSS'
#  'DORALL COLLECTION' 'GUCCI' 'YVES SAINT LAURENT' 'CERRUTI 1881'
#  'CALVIN KLEIN' 'RASASI' 'MONTALE' 'CHLOE' 'NARCISO RODRIGUEZ' 'BOUCHERON'
#  'ALINA COREL' 'REVLON' 'TED LAPIDUS' 'BRITNEY SPEARS'
#  'VAN CLEEF & ARPELS' 'ESTEE LAUDER' 'GEOFFREY BEENE' 'DOLCE & GABBANA'
#  'MANCERA' 'DIOR' 'BURBERRY' 'AIGNER' 'BENTLEY' 'VERSACE' 'JUICY COUTURE'
#  'LAURA MARS' 'GIORGIO ARMANI' 'HERMES' 'ELIZABETH ARDEN' 'BENETTON'
#  'GIORGIO BEVERLY HILLS' 'GUERLAIN' 'JEAN PAUL GAULTIER' 'AJMAL'
#  'J.CASANOVA' 'UNITED COLORS OF BENETTON' 'YSL' 'TOMMY HILFIGER'
#  'RALPH LAUREN' 'EMPORIO ARMANI' 'ARMANI' 'VALENTINO' 'ARD AL ZAAFARAN'
#  'DKNY' 'CAROLINA HERRERA' 'ELIE SAAB' 'MONTBLANC' 'LACOSTE' 'LE CHAMEAU'
#  'AVON' 'SALVATORE FERRAGAMO' 'CARRERA' 'SEDR AL-KHALEEJ PERFUMES'
#  'DUNHILL' 'TRUSSARDI' 'DUPONT' 'ANGEL SCHLESSER' 'DAVIDOFF' 'CHOPARD'
#  'CARTIER' 'JENNIFER LOPEZ' 'BVLGARI' 'FERRARI' 'ALREHAB' 'GENIE'
# ...

# %% [markdown]
# Menyamakan format penulisan pada kolom brand menjadi huruf kapital semua agartetap konsisten

# %%
df['seller'] = df['seller'].str.title()
print(df['seller'].unique())
# Out:
# ['Noon' 'Rich&Light' 'B.A.G' 'Al-Najm' 'Amlaq' 'Bismat Eatar'
#  'Star.Perfume' 'Hadayiq Baris' 'Kathya' 'Golden Perfumesعطر أصلي 100  %'
#  'Neo Lek' 'Cute Shop' 'Brand Land' 'Kaya' 'Top Langri' 'Asrar Aljamal'
#  'Make Up' 'Parfume-Stor' 'Perfumes--Addresses' 'Princess Of Beauty'
#  'King-Perfume' 'عالم المشاهير' 'Beautiful Lady' 'Boutique Wareef'
#  'Rose Gallary' 'Beauty Ideas' 'Faces' 'Moon Light' 'Shopping Life'
#  'Parisian Store' 'Parfum.1990' 'Pinch Of Perfum' 'Flower'
#  'Beauty Gallery' 'Diorworld' 'Attractive Perfume' 'Majestueuse'
#  'Beautiful Live' 'Modon' 'Emper Perfumes' 'Queen Line' 'Tiffany' 'Sedr'
#  'ثروة الجمال' 'The Beauty' 'Boutique Perfumes' 'Dior Fragrances'
#  'Number One' 'Moon Perfume' 'Ryhana Perfume' 'Beuatyone1'
#  'Noon100  % Original Genuine Product' 'Kikup'
#  'Lolita Shopno Exchange Or Return' 'Alabeer' 'Parvant Store' 'Chansles'
#  'Hawas' 'Rayhanti' 'Abu Al Tayyeb Perfumes' 'Queen Beauty'
# ...

# %%
df['seller'] = df['seller'].replace({
    'Swiss Arabian Perfumesprice Update With 15% Vat 1 July 2020': 'Swiss Arabian Perfume'
})

for col in ['seller']:
    print(df[col].unique())
# Out:
# ['Noon' 'Rich&Light' 'B.A.G' 'Al-Najm' 'Amlaq' 'Bismat Eatar'
#  'Star.Perfume' 'Hadayiq Baris' 'Kathya' 'Golden Perfumesعطر أصلي 100  %'
#  'Neo Lek' 'Cute Shop' 'Brand Land' 'Kaya' 'Top Langri' 'Asrar Aljamal'
#  'Make Up' 'Parfume-Stor' 'Perfumes--Addresses' 'Princess Of Beauty'
#  'King-Perfume' 'عالم المشاهير' 'Beautiful Lady' 'Boutique Wareef'
#  'Rose Gallary' 'Beauty Ideas' 'Faces' 'Moon Light' 'Shopping Life'
#  'Parisian Store' 'Parfum.1990' 'Pinch Of Perfum' 'Flower'
#  'Beauty Gallery' 'Diorworld' 'Attractive Perfume' 'Majestueuse'
#  'Beautiful Live' 'Modon' 'Emper Perfumes' 'Queen Line' 'Tiffany' 'Sedr'
#  'ثروة الجمال' 'The Beauty' 'Boutique Perfumes' 'Dior Fragrances'
#  'Number One' 'Moon Perfume' 'Ryhana Perfume' 'Beuatyone1'
#  'Noon100  % Original Genuine Product' 'Kikup'
#  'Lolita Shopno Exchange Or Return' 'Alabeer' 'Parvant Store' 'Chansles'
#  'Hawas' 'Rayhanti' 'Abu Al Tayyeb Perfumes' 'Queen Beauty'
# ...

# %% [markdown]
# Mengubah format penulisan pada kolom seller menggunakan format title dan juga mengubah atau menghapus beberapa kalimat yang mengandung kata promosi agar lebih konsisten.

# %% [markdown]
# ### **Outliers**

# %%
columns_to_impute = ["old_price", "new_price", 'ml', 'item_rating', 'seller_rating' ]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []
cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom               Persentase Outliers
# Unnamed: 0                          0.0
# old_price                           0.0
# new_price                           0.0
# ml                                  0.0
# item_rating                         0.0
# seller_rating                       0.0
# num_seller_ratings                  0.0

# %% [markdown]
# Menghapus outliers atau nilai ekstrem yang terdapat dalam beberapa kolom. Alasan dihapus adalah karena data outliers dibawah 10% jadi dapat kita hapus saja.

# %% [markdown]
# ## **Construct Data**

# %%
def categorize_rating(item_rating):
    if item_rating >= 4.5:
        return 'Excellent'
    elif item_rating >= 4.0:
        return 'Good'
    else:
        return 'Average'

df['item_rating_category'] = df['item_rating'].apply(categorize_rating)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'brand', 'name', 'old_price', 'new_price', 'ml',
#        'concentration', 'department', 'scents', 'base_note', 'middle_note',
#        'item_rating', 'seller', 'seller_rating', 'num_seller_ratings',
#        'item_rating_category'],
#       dtype='object')

# %%
df.head(5)
# Out:
#    Unnamed: 0            brand               name  old_price  new_price   ml  \
# 0           0     PACO RABANNE    1 Million Lucky      395.0     244.55  100
# 1           1  ROBERTO CAVALLI  Paradiso Assoluto      415.0     107.95   50
# 2           2       S.T.DUPONT        Royal Amber      265.0     186.90  100
# 3           3            GUESS     Seductive Blue      290.0     103.20  100
# 4           4  ROBERTO CAVALLI               Uomo      260.0      94.95   50
#
#   concentration department   scents  \
# 0           EDT        Men    Woody
# 1           EDP      Women   Floral
# 2           EDP     Unisex  Arabian
# 3           EDT        Men    Spicy
# 4           EDP      Women  Arabian
#
#                                      base_note  \
# 0               Oakmoss, Patchouli and Vetiver
# 1            Vanilla, Sandalwood And Patchouli
# 2                    Lemon, Mint and Wood Moss
# 3  Cashmere Wood, Moss And Rippled Sand Accord
# ...

# %% [markdown]
# Metode yang digunakan adalah mengelompokkan nilai item_rating ke dalam beberapa kategori menggunakan kondisi if–elif–else. Hal ini dilakukan supaya data rating lebih mudah dibaca, dibandingkan, dan dianalisis tanpa harus melihat angka desimal satu per satu.

# %% [markdown]
# ## **Data Reduction**

# %%
df = df.drop('Unnamed: 0', axis=1)

# %%
df.columns
# Out:
# Index(['brand', 'name', 'old_price', 'new_price', 'ml', 'concentration',
#        'department', 'scents', 'base_note', 'middle_note', 'item_rating',
#        'seller', 'seller_rating', 'num_seller_ratings',
#        'item_rating_category'],
#       dtype='object')

# %% [markdown]
# Menghapus kolom unnamed karena merupakan data kosong sehingga tidak diperlukan.

# %% [markdown]
# ## **Menyimpan Dataset (Bersih)**

# %%
df.to_csv('[Bersih] Noon Perfumes Dataset.csv', index=False)

# %% [markdown]
# # **Visualisasi Matplotlib & Seaborn**

# %% [markdown]
# ## **Import Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **Import File Lokal**

# %%
file = '/content/[Bersih] Noon Perfumes Dataset.csv'

# %%
df= pd.read_csv(file)
df
# Out:
#                 brand                      name  old_price  new_price   ml  \
# 0        PACO RABANNE           1 Million Lucky      395.0     244.55  100
# 1     ROBERTO CAVALLI         Paradiso Assoluto      415.0     107.95   50
# 2          S.T.DUPONT               Royal Amber      265.0     186.90  100
# 3               GUESS            Seductive Blue      290.0     103.20  100
# 4     ROBERTO CAVALLI                      Uomo      260.0      94.95   50
# ...               ...                       ...        ...        ...  ...
# 998             GUESS                      Dare      170.0      75.00  100
# 999          BURBERRY  For Women EDP Natural Sp      378.0     153.75  100
# 1000            JOVAN           Musk Cologne Sp       55.0      19.00   59
# 1001    SWISS ARABIAN             Layali CPO At      126.0      77.00   50
# 1002          LACOSTE        L.12.12 Blanc-Pure      347.0      94.20  100
#
#      concentration department   scents  \
# ...

# %% [markdown]
# ## **Bar Chart**

# %%
top_brand = df['brand'].value_counts().head(5).sort_values(ascending=False) # head() jumlah yang mau ditampilkan & Urutan

plt.figure(figsize=(10, 6)) # Ukuran
plt.bar(top_brand.index, top_brand.values, color='skyblue') # color warna
plt.xlabel('Brand') # keterangan X label
plt.ylabel('Jumlah Produk') # keterangan y label
plt.title('Top 5 Brand Parfum Terbanyak') # Judul
plt.xticks(rotation=45, ha='right') # rotasi teks
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
#
# Berdasarkan visualisasi bar chart, terlihat bahwa Calvin Klein memiliki jumlah produk parfum terbanyak, diikuti oleh Burberry, Hugo Boss, Roberto Cavalli, dan Dorall Collection. Hal ini menunjukkan bahwa beberapa brand besar memiliki lebih banyak variasi produk dibanding brand lainnya di dataset.
#
# **Action/Tindakan yang dapat diambil:**
#
# Brand dengan jumlah produk yang tinggi dapat dijadikan fokus utama dalam strategi pemasaran atau promosi karena memiliki variasi produk yang lebih banyak. Sementara itu, brand dengan jumlah produk yang lebih sedikit bisa menjadi peluang untuk menambah variasi produk atau meningkatkan ketersediaan stok agar dapat bersaing dengan brand yang lebih dominan.

# %% [markdown]
# ## **Pie Chart**

# %%
plt.figure(figsize=(10, 6)) # ukuran
plt.pie(df['item_rating_category'].value_counts(), labels=df['item_rating_category'].value_counts().index, autopct='%1.1f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold']) # colors (warna)
plt.title('Distribusi Kategori Rating Produk') # Judul
plt.show()

# %% [markdown]
# **Insight:**
#
# Berdasarkan pie chart distribusi kategori rating produk, sebagian besar parfum berada pada kategori Excellent (69,9%), diikuti oleh Good (22,9%), dan hanya sebagian kecil yang berada pada kategori Average (7,2%). Hal ini menunjukkan bahwa mayoritas produk parfum dalam dataset memiliki rating yang sangat baik dari pengguna.
#
# **Action/Tindakan yang dapat diambil:**
#
# Karena sebagian besar produk sudah memiliki rating tinggi, perusahaan dapat mempertahankan kualitas produk dan pelayanan agar kepuasan pelanggan tetap terjaga. Selain itu, produk dengan rating Average dapat dievaluasi lebih lanjut, misalnya dengan memperbaiki kualitas produk, deskripsi produk, atau layanan penjualan agar ratingnya dapat meningkat.

# %% [markdown]
# ## **Line Chart**

# %%
price_by_concentration = df.groupby('concentration') ['new_price'].mean()

plt.figure(figsize=(20, 6))
plt.plot(price_by_concentration.index.astype(str), price_by_concentration.values, marker='o', color='blue')
plt.title('Rata-rata Harga Parfum Berdasarkan Konsentrasi Parfum', fontsize=16)
plt.xlabel('Concentration', fontsize=20)
plt.ylabel('Rata-rata Harga', fontsize=20)
plt.grid(True)
plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
#
# Berdasarkan line chart, terlihat bahwa parfum dengan konsentrasi EDP memiliki rata-rata harga paling tinggi, diikuti oleh EDT dan EDC, sedangkan Oil dan PDT memiliki rata-rata harga yang lebih rendah. Hal ini menunjukkan bahwa jenis konsentrasi parfum mempengaruhi harga produk, di mana konsentrasi yang lebih populer seperti EDP cenderung memiliki harga yang lebih tinggi.
#
# **Action/Tindakan yang dapat diambil:**
#
# Perusahaan dapat lebih fokus memasarkan produk dengan konsentrasi EDP karena memiliki nilai jual yang lebih tinggi. Selain itu, produk dengan konsentrasi lain seperti EDT atau EDC juga dapat dipromosikan sebagai alternatif yang lebih terjangkau bagi konsumen dengan budget berbeda.

# %% [markdown]
# ## **Histogram**

# %%
plt.figure(figsize=(8, 5))
plt.hist(df['new_price'], bins=20, color='pink', edgecolor='black')
plt.title('Distribusi Harga Parfum')
plt.xlabel('Harga')
plt.ylabel('Jumlah Produk')
plt.show()

# %% [markdown]
# **Insight:**
#
# Berdasarkan histogram distribusi harga parfum, terlihat bahwa sebagian besar produk berada pada rentang harga menengah, sementara jumlah produk dengan harga sangat tinggi atau sangat rendah relatif lebih sedikit. Hal ini menunjukkan bahwa mayoritas parfum dalam dataset dijual pada harga yang cukup terjangkau bagi konsumen.
#
# **Action/Tindakan yang dapat diambil:**
#
# Perusahaan dapat lebih fokus menyediakan dan mempromosikan parfum pada rentang harga menengah karena kemungkinan memiliki permintaan yang lebih tinggi. Selain itu, produk dengan harga tinggi dapat diposisikan sebagai produk premium, sedangkan produk dengan harga lebih rendah dapat ditargetkan untuk menarik konsumen dengan budget terbatas.

# %% [markdown]
# ## **Box Plot**

# %%
top_brands = df['brand'].value_counts().head(5).index
brand_price_data = df[df['brand'].isin(top_brands)]

plt.figure(figsize=(12, 7)) # Ukuran figure
brand_price_data.boxplot(column='new_price', by='brand', ax=plt.gca(), grid=False, patch_artist=True, medianprops=dict(color='red'))
plt.title('Perbandingan Harga Berdaarkan Brand', fontsize=16) # Judul
plt.xlabel('Brand', fontsize=12) # X Keterangan
plt.ylabel('Harga', fontsize=12) # Y Keterangan
plt.xticks(rotation=45, ha='right')
plt.suptitle('') # Menghilangkan judul default dari boxplot.by
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
#
# Berdasarkan boxplot perbandingan harga berdasarkan brand, terlihat bahwa setiap brand memiliki distribusi harga yang berbeda. Beberapa brand seperti Burberry, Hugo Boss, dan Roberto Cavalli memiliki variasi harga yang cukup luas dan terdapat beberapa outlier (harga yang jauh lebih tinggi dari rata-rata). Sementara itu, brand seperti Calvin Klein memiliki distribusi harga yang lebih stabil, dan Dorall Collection memiliki harga yang jauh lebih rendah dibanding brand lainnya.
#
# **Action/Tindakan yang dapat diambil:**
#
# Brand dengan harga tinggi seperti Burberry atau Hugo Boss dapat diposisikan sebagai produk premium untuk segmen konsumen tertentu. Sedangkan brand dengan harga lebih rendah seperti Dorall Collection dapat ditargetkan untuk konsumen yang mencari parfum dengan harga lebih terjangkau. Selain itu, variasi harga yang besar pada beberapa brand dapat dianalisis lebih lanjut untuk memahami strategi penetapan harga dan preferensi pasar.

# %% [markdown]
# ## **Scatter Plot**

# %%
plt.figure(figsize=(10, 6)) # Ukuran
plt.scatter(df['old_price'], df['new_price'], alpha=0.7, color='teal') # Color (Warna)
plt.title('Harga Lama vs Harga Baru', fontsize=16) # Judul
plt.xlabel('Harga Lama', fontsize=12) # X Keterangan
plt.ylabel('Harga Baru', fontsize=12) # Y Keterangan
plt.grid(False)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
#
# Scatter plot menunjukkan adanya hubungan positif antara harga lama (old_price) dan harga baru (new_price). Titik-titik data membentuk pola naik dari kiri bawah ke kanan atas, yang berarti semakin tinggi harga lama suatu produk, maka harga barunya juga cenderung semakin tinggi. Hal ini menunjukkan bahwa harga baru kemungkinan merupakan hasil penyesuaian atau diskon dari harga lama. Selain itu, terlihat beberapa produk dengan harga lama sangat tinggi tetapi harga baru tetap lebih rendah, yang menunjukkan adanya potongan harga pada beberapa produk.
#
# **Action/Tindakan yang dapat diambil:**
#
# Perusahaan dapat memanfaatkan pola ini untuk mengatur strategi diskon atau promosi yang lebih menarik, terutama pada produk dengan harga lama tinggi agar terlihat lebih menarik bagi konsumen. Selain itu, produk dengan harga tinggi bisa diberikan diskon yang jelas agar meningkatkan minat pembeli tanpa harus menurunkan nilai produk secara signifikan.

# %% [markdown]
# ## **Bubble Chart**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='ml', y='new_price', size='num_seller_ratings', hue='concentration', data=df, sizes=(50, 1000), alpha=0.7, palette='viridis')
plt.title('Ukuran Parfum vs Harga (Ukuran: Jumlah Seller Ratings, Warna: Konsentrasi)', fontsize=16)
plt.xlabel('Ukuran (ml)', fontsize=12)
plt.ylabel('Harga', fontsize=12)
plt.grid(True)
plt.legend(title='concentration', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight:**
#
# Berdasarkan bubble chart, terlihat bahwa ukuran parfum yang lebih besar (ml) cenderung memiliki harga yang lebih tinggi, meskipun tidak selalu berbanding lurus. Beberapa parfum dengan ukuran yang sama memiliki harga yang berbeda tergantung pada konsentrasi parfum (seperti EDT, EDP, atau PDT). Selain itu, ukuran bubble menunjukkan jumlah seller ratings, sehingga produk dengan bubble lebih besar menandakan produk tersebut memiliki lebih banyak penilaian dan kemungkinan lebih populer di pasar.
#
# **Action/Tindakan yang dapat diambil:**
#
# Perusahaan dapat menyediakan variasi ukuran parfum untuk menjangkau berbagai segmen konsumen, misalnya ukuran kecil untuk konsumen yang ingin mencoba produk dengan harga lebih terjangkau dan ukuran besar untuk konsumen yang menginginkan produk dengan nilai lebih. Selain itu, produk dengan jumlah seller ratings yang tinggi dapat diprioritaskan dalam promosi karena menunjukkan tingkat kepercayaan dan minat konsumen yang lebih besar.

# %% [markdown]
# ## **Heatmap**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['old_price', 'new_price', 'ml', 'item_rating', 'seller_rating', 'num_seller_ratings']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Heatmap Korelasi Antar Variabel Numerik')
plt.show()

# %% [markdown]
# **Insight:**
#
# Berdasarkan heatmap korelasi antar variabel numerik, terlihat bahwa old_price dan new_price memiliki korelasi yang cukup kuat (sekitar 0.84), yang berarti harga lama dan harga baru sangat berkaitan karena biasanya harga baru merupakan harga setelah diskon dari harga lama. Sementara itu, variabel lain seperti ml, item_rating, seller_rating, dan num_seller_ratings memiliki korelasi yang cukup rendah terhadap harga maupun satu sama lain. Hal ini menunjukkan bahwa faktor seperti ukuran parfum atau rating tidak memiliki hubungan yang kuat dengan harga produk dalam dataset ini.
#
# **Action/Tindakan yang dapat diambil:**
#
# Perusahaan dapat menggunakan informasi hubungan harga lama dan harga baru untuk mengelola strategi diskon atau promosi secara lebih efektif. Selain itu, karena rating produk dan ukuran parfum tidak terlalu berkorelasi dengan harga, perusahaan dapat tetap menjaga kualitas produk dan pelayanan tanpa harus selalu menaikkan harga produk.
